# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib_inline.backend_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

# !pip install tiktoken
import tiktoken
# Out:
# Requirement already satisfied: tiktoken in /Users/jane/Desktop/claude-code-projects/agent/agents/.venv/lib/python3.12/site-packages (0.12.0)
# Requirement already satisfied: regex>=2022.1.18 in /Users/jane/Desktop/claude-code-projects/agent/agents/.venv/lib/python3.12/site-packages (from tiktoken) (2025.9.18)
# Requirement already satisfied: requests>=2.26.0 in /Users/jane/Desktop/claude-code-projects/agent/agents/.venv/lib/python3.12/site-packages (from tiktoken) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jane/Desktop/claude-code-projects/agent/agents/.venv/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jane/Desktop/claude-code-projects/agent/agents/.venv/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jane/Desktop/claude-code-projects/agent/agents/.venv/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jane/Desktop/claude-code-projects/agent/agents/.venv/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken) (2025.10.5)
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# GPT-4's tokenizer
tokenizer = tiktoken.get_encoding('cl100k_base')

# %%
import requests
import re
text = requests.get('https://www.gutenberg.org/files/35/35-0.txt').text
tmTokens = tokenizer.encode(text)

# %%
# split by punctuation
words = re.split(r'([,.:;—?_!"“()\']|--|\s)',text)
words = [item.strip() for item in words if item.strip()]

tokenCount = np.zeros((len(words),2),dtype=int)

for idx,w in enumerate(words):
  tokenCount[idx,0] = len(w) # first column is the length of the word
  tokenCount[idx,1] = len(tokenizer.encode(w)) # second column is the number of tokens

# %%
plt.figure(figsize=(12,4))

offsetsX = np.random.randn(len(words))/20
offsetsY = np.random.randn(len(words))/20

plt.plot(tokenCount[:,0]+offsetsX,tokenCount[:,1]+offsetsY,'k.',alpha=.5)
plt.gca().set(xlabel='Word lengths',ylabel='Encoded token count',xticks=np.arange(1,np.max(tokenCount[:,0])+1))

plt.show()

# %%
# find words with characters
wordsWith14Chars = np.where(tokenCount[:,0]==14)[0]

# print their tokens
for idx in wordsWith14Chars:
  this_decode = [ tokenizer.decode([t]) for t in tokenizer.encode(words[idx]) ]
  print(f'"{words[idx]}" comprises {this_decode}')
# Out:
# "intermittently" comprises ['inter', 'mitt', 'ently']
# "mathematicians" comprises ['math', 'ematic', 'ians']
# "Time-Dimension" comprises ['Time', '-D', 'imension']
# "Time-Dimension" comprises ['Time', '-D', 'imension']
# "Time-Dimension" comprises ['Time', '-D', 'imension']
# "investigations" comprises ['invest', 'ig', 'ations']
# "Psychologist’s" comprises ['Psych', 'ologist', '’s']
# "potentialities" comprises ['potential', 'ities']
# "incredibleness" comprises ['in', 'cred', 'ib', 'leness']
# "aforementioned" comprises ['a', 'fore', 'mentioned']
# "wool-gathering" comprises ['wo', 'ol', '-g', 'athering']
# "interpretation" comprises ['interpret', 'ation']
# "Nebuchadnezzar" comprises ['N', 'eb', 'uch', 'ad', 'ne', 'zz', 'ar']
# "Psychologist’s" comprises ['Psych', 'ologist', '’s']
# "overwhelmingly" comprises ['over', 'whelming', 'ly']
# "disappointment" comprises ['dis', 'appointment']
# "interrogations" comprises ['inter', 'rog', 'ations']
# "conversational" comprises ['con', 'vers', 'ational']
# "characteristic" comprises ['character', 'istic']
# "specialisation" comprises ['special', 'isation']
# "interpretation" comprises ['interpret', 'ation']
# "interpretation" comprises ['interpret', 'ation']
# "self-restraint" comprises ['self', '-re', 'straint']
# "expostulations" comprises ['ex', 'post', 'ulations']
# "ill-controlled" comprises ['ill', '-controlled']
# "differentiated" comprises ['different', 'iated']
# "long-continued" comprises ['long', '-', 'continued']
# "stratification" comprises ['str', 'at', 'ification']
# "Undergrounders" comprises ['Under', 'ground', 'ers']
# "south-westward" comprises ['south', '-west', 'ward']
# "self-deception" comprises ['self', '-de', 'ception']
# "safety-matches" comprises ['s', 'afety', '-m', 'atches']
# "constellations" comprises ['const', 'ell', 'ations']
# "constellations" comprises ['const', 'ell', 'ations']
# "discriminating" comprises ['disc', 'rim', 'inating']
# "north-eastward" comprises ['north', '-east', 'ward']
# "disinclination" comprises ['dis', 'incl', 'ination']
# "disappointment" comprises ['dis', 'appointment']
# "North-eastward" comprises ['North', '-east', 'ward']
# "south-eastward" comprises ['south', '-east', 'ward']
# "mountaineering" comprises ['mount', 'aine', 'ering']
# "north-eastward" comprises ['north', '-east', 'ward']
# "starting-point" comprises ['starting', '-point']
# "blood-drinking" comprises ['blood', '-dr', 'inking']
